# %% [markdown]
# This notebook exists to help perform some transformations and inspections of data.  Goal is to eventually collapse this into a .py file.
#
# Data Sources / credits:
# * Census data selector CSV download from: https://www.census.gov/data-tools/demo/saipe/#/?map_geoSelector=aa_c&s_year=2018,2017,2015,2009&map_yearSelector=2009
# * Andrew's API key: 809a11b265cd8f07473e64706d722d9c5aa77b23

# %%
# Install some helpful libraries
#!pip install geopy

# This notebook will analyze two datasets: the college town and hometown
# input sources.  True/False toggles which one you're working on.  Default
# set to False, for timeliness.
hometown = False

# Importing necessary libraries
import pandas as pd
import geopy.geocoders
from geopy.geocoders import Nominatim
from functools import partial
from geopy.extra.rate_limiter import RateLimiter

# Setup our geolocator
geopy.geocoders.options.default_timeout = 7
geolocator = Nominatim(user_agent="college-town-econ-extractor-v2")
geocode = partial(geolocator.geocode, language="en", min_delay_seconds=1)

# %%
# Reading the files
if hometown == False:
    fpath = '../college-input.csv'
else:
    fpath = '../hometown-input.csv'
city_df = pd.read_csv(fpath,header=0)
city_df['county'],city_df['state'],city_df['poverty_pct'],city_df['med_income']='','','',''
fpath = './census/SAIPESNC_30MAY20_00_49_30_76.csv'
census_df = pd.read_csv(fpath)

# %%
# Identify counties and econ data for each city
# Starting with a single year
year = 2018

for i in range(city_df.shape[0]):
    city,state = city_df['Geographic Location'][i].split(",")
    location = geolocator.geocode(city+state+" usa")
    try:
        loc = location[0].split(',')[1:3]
        #print(city,state," - ",end="")
        #print(location)
        cty = ""
        for l in location[0].split(','):
            if 'county' in l.lower():
                cty = l
            else:
                if 'parish' in l.lower():
                    cty = l
        if cty == "":
            print("County not found for:",location)
            continue
        city_df.at[i,'county'],city_df.at[i,'state']=cty,state
        for n in range(census_df.shape[0]):
            if census_df['State / County Name'][n].split("(")[0].strip() == cty.strip():
                if int(census_df['Year'][n]) == year:
                    city_df.at[i,'poverty_pct'],city_df['med_income'] = float(census_df['All Ages in Poverty Percent'][n]),census_df['Median Household Income in Dollars'][n]
    except TypeError:
        continue
# Out:
# County not found for: Indianapolis, Marion, Indiana, United States of America
# County not found for: Little Rock, Arkansas, United States of America
# County not found for: PLAZA USA, 環七通り, 代田, 船橋, 東京都, 世田谷区, 156-0042, 日本 (Japan)
# County not found for: West Valley City, Utah, United States of America
# County not found for: Waterloo, Iowa, United States of America
# County not found for: Washington, District of Columbia, 20500, United States of America
# County not found for: Racine, Wisconsin, United States of America
# County not found for: Madison Middle School, Rhodes Street, Madison, Illinois, 62040, United States of America
# County not found for: USA Park, Rua Voluntários da Pátria, Botafogo, Zona Sul do Rio de Janeiro, Rio de Janeiro, Região Geográfica Imediata do Rio de Janeiro, Região Metropolitana do Rio de Janeiro, Região Geográfica Intermediária do Rio de Janeiro, Rio de Janeiro, Região Sudeste, 22270-000, Brasil
# County not found for: Swisher, Iowa, United States of America
# County not found for: Pawtucket, Rhode Island, United States of America
# County not found for: Saint Louis, City of Saint Louis, Missouri, 63102-1102, United States of America
# County not found for: West Bountiful, Utah, United States of America
# County not found for: Westerly, Washington, Rhode Island, United States of America
# County not found for: Stewartsville, Greenwich Township, New Jersey, 08886, United States of America
# County not found for: Syracuse, Utah, 84075, United States of America
# County not found for: Speedway, Marion, Indiana, 46224, United States of America
# County not found for: Curtice, Allen Township, Ohio, 43412, United States of America

# %%
city_df
# Out:
#      Geographic Location                  county state poverty_pct med_income
# 0           Lakeland, FL             Polk County    FL         9.6    $69,212
# 1               Howe, TX          Grayson County    TX        18.4    $69,212
# 2          Northport, AL       Tuscaloosa County    AL        16.8    $69,212
# 3            Bristow, VA   Prince William County    VA         6.4    $69,212
# 4          Covington, GA           Newton County    GA        22.3    $69,212
# ...                  ...                     ...   ...         ...        ...
# 3636           Watts, CA      Los Angeles County    CA        14.2    $69,212
# 3637       Groesbeck, TX        Limestone County    TX        22.2    $69,212
# 3638           Ogden, UT            Weber County    UT         9.4    $69,212
# 3639         Connell, WA         Franklin County    WA        13.4    $69,212
# 3640   West Richland, WA           Benton County    WA         9.8    $69,212
#
# [3641 rows x 5 columns]

# %%
census_df
# Out:
#        Year  State  County ID   State / County Name  \
# 0      2018      0          0         United States
# 1      2017      0          0         United States
# 2      2015      0          0         United States
# 3      2009      0          0         United States
# 4      2018      1       1000               Alabama
# ...     ...    ...        ...                   ...
# 12772  2009     56      56043  Washakie County (WY)
# 12773  2018     56      56045    Weston County (WY)
# 12774  2017     56      56045    Weston County (WY)
# 12775  2015     56      56045    Weston County (WY)
# 12776  2009     56      56045    Weston County (WY)
#
#       All Ages SAIPE Poverty Universe All Ages in Poverty Count  \
# 0                         319,184,033                41,852,315
# 1                         317,741,588                42,583,651
# 2                         313,476,400                46,153,077
# 3                         299,026,555                42,868,163
# 4                           4,763,811                   801,758
# ...                               ...                       ...
# 12772                           7,725                       889
# 12773                           6,595                       777
# 12774                           6,573                       699
# 12775                           6,884                       675
# 12776                           6,698                       663
#
#       All Ages in Poverty Count LB 90% All Ages in Poverty Count UB 90%  \
# 0                           41,619,366                       42,085,264
# 1                           42,342,619                       42,824,683
# 2                           45,878,016                       46,428,138
# 3                           42,631,574                       43,104,752
# 4                              785,668                          817,848
# ...                                ...                              ...
# 12772                              661                            1,117
# 12773                              608                              946
# 12774                              541                              857
# 12775                              520                              830
# 12776                              507                              819
#
#       90% Confidence Interval (All Ages in Poverty Count)  \
# 0                               41,619,366 to 42,085,264
# 1                               42,342,619 to 42,824,683
# 2                               45,878,016 to 46,428,138
# 3                               42,631,574 to 43,104,752
# 4                                     785,668 to 817,848
# ...                                                  ...
# 12772                                       661 to 1,117
# 12773                                         608 to 946
# 12774                                         541 to 857
# 12775                                         520 to 830
# 12776                                         507 to 819
#
#        All Ages in Poverty Percent  ...  Under Age 5 in Poverty Count UB 90%  \
# 0                             13.1  ...                            3,802,546
# 1                             13.4  ...                            3,985,293
# 2                             14.7  ...                            4,499,317
# 3                             14.3  ...                            4,907,599
# 4                             16.8  ...                               77,840
# ...                            ...  ...                                  ...
# 12772                         11.5  ...                                  NaN
# 12773                         11.8  ...                                  NaN
# 12774                         10.6  ...                                  NaN
# 12775                          9.8  ...                                  NaN
# 12776                          9.9  ...                                  NaN
#
#        90% Confidence Interval (Under Age 5 in Poverty Count)  \
# 0                                 3,714,862 to 3,802,546
# 1                                 3,880,645 to 3,985,293
# 2                                 4,397,105 to 4,499,317
# 3                                 4,792,377 to 4,907,599
# 4                                       69,990 to 77,840
# ...                                                  ...
# 12772                                                NaN
# 12773                                                NaN
# 12774                                                NaN
# 12775                                                NaN
# 12776                                                NaN
#
#       Under Age 5 in Poverty Percent Under Age 5 in Poverty Percent LB 90%  \
# 0                               19.5                                  19.3
# 1                               20.2                                  19.9
# 2                               22.8                                  22.5
# 3                               23.2                                  23.0
# 4                               26.0                                  24.6
# ...                              ...                                   ...
# 12772                            NaN                                   NaN
# 12773                            NaN                                   NaN
# 12774                            NaN                                   NaN
# 12775                            NaN                                   NaN
# 12776                            NaN                                   NaN
#
#       Under Age 5 in Poverty Percent UB 90%  \
# 0                                      19.7
# 1                                      20.5
# 2                                      23.1
# 3                                      23.5
# 4                                      27.4
# ...                                     ...
# 12772                                   NaN
# 12773                                   NaN
# 12774                                   NaN
# 12775                                   NaN
# 12776                                   NaN
#
#       90% Confidence Interval (Under Age 5 in Poverty Percent)  \
# 0                                           19.3 to 19.7
# 1                                           19.9 to 20.5
# 2                                           22.5 to 23.1
# 3                                           23.0 to 23.5
# 4                                           24.6 to 27.4
# ...                                                  ...
# 12772                                                NaN
# 12773                                                NaN
# 12774                                                NaN
# 12775                                                NaN
# 12776                                                NaN
#
#       Median Household Income in Dollars  \
# 0                                $61,937
# 1                                $60,336
# 2                                $55,775
# 3                                $50,221
# 4                                $49,881
# ...                                  ...
# 12772                            $47,098
# 12773                            $54,319
# 12774                            $56,214
# 12775                            $60,986
# 12776                            $50,642
#
#       Median Household Income in Dollars LB 90%  \
# 0                                       $61,843
# 1                                       $60,250
# 2                                       $55,690
# 3                                       $50,147
# 4                                       $49,123
# ...                                         ...
# 12772                                   $42,536
# 12773                                   $48,315
# 12774                                   $50,250
# 12775                                   $54,751
# 12776                                   $45,337
#
#        Median Household Income in Dollars UB 90%  \
# 0                                        $62,031
# 1                                        $60,422
# 2                                        $55,860
# 3                                        $50,295
# 4                                        $50,639
# ...                                          ...
# 12772                                    $51,659
# 12773                                    $60,323
# 12774                                    $62,178
# 12775                                    $67,221
# 12776                                    $55,947
#
#        90% Confidence Interval (Median Household Income in Dollars)
# 0                                     $61,843 to $62,031
# 1                                     $60,250 to $60,422
# 2                                     $55,690 to $55,860
# 3                                     $50,147 to $50,295
# 4                                     $49,123 to $50,639
# ...                                                  ...
# 12772                                 $42,536 to $51,659
# 12773                                 $48,315 to $60,323
# 12774                                 $50,250 to $62,178
# 12775                                 $54,751 to $67,221
# 12776                                 $45,337 to $55,947
#
# [12777 rows x 44 columns]

# %%
if hometown == False:
    city_df.to_csv('../collegetown-econ-output.csv', index=False)
else:
    city_df.to_csv('../hometown-econ-output.csv', index=False)
